# %% [markdown]
# ## Unzip all inspection reports

# %%
import os, zipfile
import glob

path = 'D:/001_Projects/01 - GIPTN/02 - Application development/03 - Bus Inspection/01 - Inspections/July 2018 Bus inspection reports/'
extension = ".zip"

# %%
zip_files = glob.glob(path + '/*.zip')

for zip_filename in zip_files:
    dir_name = os.path.splitext(zip_filename)[0]
    os.mkdir(dir_name)
    zip_handler = zipfile.ZipFile(zip_filename, "r")
    zip_handler.extractall(dir_name)

# %% [markdown]
# # Read Inspection data

# %%
import pandas as pd
import os.path
import re
path = 'D:/001_Projects/01 - GIPTN/02 - Application development/03 - Bus Inspection/01 - Inspections/July 2018 Bus inspection reports/Extracted Reports/'

# %%
file_list = []
for root, dirs, files in os.walk(path):
    for filename in files:
        if filename.endswith('.csv'):
            file_list.append(os.path.join(root, filename)) 
    df_list = [pd.read_csv(file, index_col = 'Survey ID', usecols = range(0, 161), nrows=1) for file in file_list]
    df_list_bd = [pd.read_csv(file, usecols = range(0, 172)) for file in file_list]
if df_list:
    inspection_data = pd.concat(df_list, axis=0, sort=False) 
    bd_data = pd.concat(df_list_bd, axis=0, sort=False)

# %% [markdown]
# ## Adjust column names, filter and restructure inspection data

# %%
inspection_df = inspection_data.drop(['Section Name', 'Vehicle Class', 
                            'Section Name.1', 'Exterior Inspection',
                            'Section Name.3', 'Interior Inspection', 
                            'Section Name.2', 'Vehicle Lights Inspection',
                            'When does the vehicles roadworthy expire?'], axis=1)
inspection_df = inspection_df[inspection_df.columns.drop(list(inspection_df.filter(regex=' - No')))]
inspection_df = inspection_df[inspection_df.columns.drop(list(inspection_df.filter(regex='Image')))]
inspection_df = inspection_df[inspection_df.columns.drop(list(inspection_df.filter(regex='Photo')))]
inspection_df = inspection_df[inspection_df.columns.drop(list(inspection_df.filter(regex='Details')))]
inspection_df = inspection_df[inspection_df.columns.drop(list(inspection_df.filter(regex='details')))]
inspection_df = inspection_df[inspection_df.columns.drop(list(inspection_df.filter(regex='Date by')))]
inspection_df.columns = inspection_df.columns.str.replace("Are ", "")
inspection_df.columns = inspection_df.columns.str.replace("there ", "")
inspection_df.columns = inspection_df.columns.str.replace("any  ", "")
inspection_df.columns = inspection_df.columns.str.replace("Is ", "")
inspection_df.columns = inspection_df.columns.str.replace("the ", "")
inspection_df.columns = inspection_df.columns.str.replace("any ", "")
inspection_df.columns = inspection_df.columns.str.replace(".1", "")
inspection_df.columns = inspection_df.columns.str.replace(" - Yes", "")
inspection_df.columns = inspection_df.columns.str.replace("?", "")
inspection_defects = pd.melt(inspection_df, id_vars=['Survey Name', 'Date and Time of Survey',
   'Vehicle Class (Value)', 'Odometer Reading'], var_name= 'Defect', value_name ='Present')
inspection_defects = inspection_defects.fillna('')
inspection_defects_filtered = inspection_defects[inspection_defects['Present'] == 'Yes']

# %%
inspection_defects_filtered.columns
# Out:
# Index(['Survey Name', 'Date and Time of Survey', 'Vehicle Class (Value)',
#        'Odometer Reading', 'Defect', 'Present'],
#       dtype='object')

# %% [markdown]
# ## Restructure Body Damage data

# %%
bd_filtered = bd_data[pd.notnull(bd_data['Nature of Damage'])]
bd_filled = bd_filtered.fillna(method='ffill')
bd_filled = bd_filled.set_index('Survey ID')
bd_filled = bd_filled.filter(items=['Survey Name', 'Date and Time of Survey', 'Vehicle Class (Value)', 'Last Modified By', 'Last Modified At', 'Nature of Damage'])
bd_filled
# Out:
#                                      Survey Name Date and Time of Survey  \
# Survey ID
# 5e2a9b76-63e8-715d-9fd0-02fad3d2950f     Bus 100       4 Aug 2018, 14:58
# 5e2a9b76-63e8-715d-9fd0-02fad3d2950f     Bus 100       4 Aug 2018, 14:58
# 5e2a9b76-63e8-715d-9fd0-02fad3d2950f     Bus 100       4 Aug 2018, 14:58
# 5e2a9b76-63e8-715d-9fd0-02fad3d2950f     Bus 100       4 Aug 2018, 14:58
# 6f73896f-55a9-04e3-0d86-5a27ff2e0301     Bus 101      31 Jul 2018, 11:15
# 6f73896f-55a9-04e3-0d86-5a27ff2e0301     Bus 101      31 Jul 2018, 11:15
# c9f4548a-c060-567f-484e-b674ff89dfb3     Bus 102       5 Aug 2018, 14:53
# 2b7b0bf2-2c6f-81d4-55af-96d216ecdf48     Bus 103      13 Jul 2018, 09:26
# 2b7b0bf2-2c6f-81d4-55af-96d216ecdf48     Bus 103      13 Jul 2018, 09:26
# 2b7b0bf2-2c6f-81d4-55af-96d216ecdf48     Bus 103      13 Jul 2018, 09:26
# 2b7b0bf2-2c6f-81d4-55af-96d216ecdf48     Bus 103      13 Jul 2018, 09:26
# 2b7b0bf2-2c6f-81d4-55af-96d216ecdf48     Bus 103      13 Jul 2018, 09:26
# 2b7b0bf2-2c6f-81d4-55af-96d216ecdf48     Bus 103      13 Jul 2018, 09:26
# 2b7b0bf2-2c6f-81d4-55af-96d216ecdf48     Bus 103      13 Jul 2018, 09:26
# 2b7b0bf2-2c6f-81d4-55af-96d216ecdf48     Bus 103      13 Jul 2018, 09:26
# 8b0625fa-d153-2b91-55cd-4557341ff5ef     Bus 105      25 Jul 2018, 11:48
# 8b0625fa-d153-2b91-55cd-4557341ff5ef     Bus 105      25 Jul 2018, 11:48
# 8b0625fa-d153-2b91-55cd-4557341ff5ef     Bus 105      25 Jul 2018, 11:48
# 8b0625fa-d153-2b91-55cd-4557341ff5ef     Bus 105      25 Jul 2018, 11:48
# 8b0625fa-d153-2b91-55cd-4557341ff5ef     Bus 105      25 Jul 2018, 11:48
# 8b0625fa-d153-2b91-55cd-4557341ff5ef     Bus 105      25 Jul 2018, 11:48
# 8b0625fa-d153-2b91-55cd-4557341ff5ef     Bus 105      25 Jul 2018, 11:48
# d924817c-d2c8-f9b4-cd70-8b0f776f9779     Bus 106       4 Aug 2018, 13:54
# d924817c-d2c8-f9b4-cd70-8b0f776f9779     Bus 106       4 Aug 2018, 13:54
# d924817c-d2c8-f9b4-cd70-8b0f776f9779     Bus 106       4 Aug 2018, 13:54
# d924817c-d2c8-f9b4-cd70-8b0f776f9779     Bus 106       4 Aug 2018, 13:54
# 156864de-cd78-65ac-f4cc-abe292df23e2     Bus 107      25 Jul 2018, 12:13
# 156864de-cd78-65ac-f4cc-abe292df23e2     Bus 107      25 Jul 2018, 12:13
# 156864de-cd78-65ac-f4cc-abe292df23e2     Bus 107      25 Jul 2018, 12:13
# 156864de-cd78-65ac-f4cc-abe292df23e2     Bus 107      25 Jul 2018, 12:13
# ...                                          ...                     ...
# 5a2ee223-92ac-bb9f-5b55-e3a75332aab7     Bus 222       4 Aug 2018, 14:29
# 5a2ee223-92ac-bb9f-5b55-e3a75332aab7     Bus 222       4 Aug 2018, 14:29
# 5a2ee223-92ac-bb9f-5b55-e3a75332aab7     Bus 222       4 Aug 2018, 14:29
# 5a2ee223-92ac-bb9f-5b55-e3a75332aab7     Bus 222       4 Aug 2018, 14:29
# 57a4d476-ab86-94fd-a47e-2dd623cfb1b0     Bus 223       6 Aug 2018, 16:23
# 57a4d476-ab86-94fd-a47e-2dd623cfb1b0     Bus 223       6 Aug 2018, 16:23
# 57a4d476-ab86-94fd-a47e-2dd623cfb1b0     Bus 223       6 Aug 2018, 16:23
# 57a4d476-ab86-94fd-a47e-2dd623cfb1b0     Bus 223       6 Aug 2018, 16:23
# b03f8129-1766-b454-4d69-4511cc2ca77b     Bus 225       3 Aug 2018, 12:34
# b03f8129-1766-b454-4d69-4511cc2ca77b     Bus 225       3 Aug 2018, 12:34
# b03f8129-1766-b454-4d69-4511cc2ca77b     Bus 225       3 Aug 2018, 12:34
# b03f8129-1766-b454-4d69-4511cc2ca77b     Bus 225       3 Aug 2018, 12:34
# 9c9ae174-6101-bd8e-bae5-c7a12043b593     Bus 226       1 Aug 2018, 11:42
# 9c9ae174-6101-bd8e-bae5-c7a12043b593     Bus 226       1 Aug 2018, 11:42
# a9b5c1ae-33ac-ee6f-fdab-c1f658d14ebc     Bus 227       2 Aug 2018, 14:34
# b7f3e8ae-0b9f-cdcd-06a0-03b559b4340e     Bus 228       6 Aug 2018, 16:23
# b7f3e8ae-0b9f-cdcd-06a0-03b559b4340e     Bus 228       6 Aug 2018, 16:23
# b7f3e8ae-0b9f-cdcd-06a0-03b559b4340e     Bus 228       6 Aug 2018, 16:23
# a060e5b7-389a-2b23-2341-556480b0aa44     Bus 229       6 Aug 2018, 16:50
# a060e5b7-389a-2b23-2341-556480b0aa44     Bus 229       6 Aug 2018, 16:50
# a060e5b7-389a-2b23-2341-556480b0aa44     Bus 229       6 Aug 2018, 16:50
# a060e5b7-389a-2b23-2341-556480b0aa44     Bus 229       6 Aug 2018, 16:50
# d3a61267-f4a9-7064-3d04-7bcb2967458b     Bus 232       1 Aug 2018, 10:42
# d3a61267-f4a9-7064-3d04-7bcb2967458b     Bus 232       1 Aug 2018, 10:42
# 69c37fa0-e110-4a40-38b9-49dcfe79ab56     Bus 311       7 Aug 2018, 12:04
# 22fae19c-22dd-7844-7562-2d6153f2ef9d     Bus 316       7 Aug 2018, 11:56
# 3ee0e001-82e5-1cf4-8c71-e0756f34e4c2     Bus 326       5 Aug 2018, 14:01
# 56ac3f97-8eda-e8dc-7da8-fcdf3232b160     Bus 329       7 Aug 2018, 12:15
# d9d79e7e-0247-b942-4e72-8d3422e2ea80     Bus 330       5 Aug 2018, 14:48
# 01fa0dff-5e9a-28b8-be09-25927e72a6c0     Bus 334       7 Aug 2018, 11:51
#
#                                      Vehicle Class (Value)  \
# Survey ID
# 5e2a9b76-63e8-715d-9fd0-02fad3d2950f          Standard Bus
# 5e2a9b76-63e8-715d-9fd0-02fad3d2950f          Standard Bus
# 5e2a9b76-63e8-715d-9fd0-02fad3d2950f          Standard Bus
# 5e2a9b76-63e8-715d-9fd0-02fad3d2950f          Standard Bus
# 6f73896f-55a9-04e3-0d86-5a27ff2e0301          Standard Bus
# 6f73896f-55a9-04e3-0d86-5a27ff2e0301          Standard Bus
# c9f4548a-c060-567f-484e-b674ff89dfb3          Standard Bus
# 2b7b0bf2-2c6f-81d4-55af-96d216ecdf48          Standard Bus
# 2b7b0bf2-2c6f-81d4-55af-96d216ecdf48          Standard Bus
# 2b7b0bf2-2c6f-81d4-55af-96d216ecdf48          Standard Bus
# 2b7b0bf2-2c6f-81d4-55af-96d216ecdf48          Standard Bus
# 2b7b0bf2-2c6f-81d4-55af-96d216ecdf48          Standard Bus
# 2b7b0bf2-2c6f-81d4-55af-96d216ecdf48          Standard Bus
# 2b7b0bf2-2c6f-81d4-55af-96d216ecdf48          Standard Bus
# 2b7b0bf2-2c6f-81d4-55af-96d216ecdf48          Standard Bus
# 8b0625fa-d153-2b91-55cd-4557341ff5ef          Standard Bus
# 8b0625fa-d153-2b91-55cd-4557341ff5ef          Standard Bus
# 8b0625fa-d153-2b91-55cd-4557341ff5ef          Standard Bus
# 8b0625fa-d153-2b91-55cd-4557341ff5ef          Standard Bus
# 8b0625fa-d153-2b91-55cd-4557341ff5ef          Standard Bus
# 8b0625fa-d153-2b91-55cd-4557341ff5ef          Standard Bus
# 8b0625fa-d153-2b91-55cd-4557341ff5ef          Standard Bus
# d924817c-d2c8-f9b4-cd70-8b0f776f9779          Standard Bus
# d924817c-d2c8-f9b4-cd70-8b0f776f9779          Standard Bus
# d924817c-d2c8-f9b4-cd70-8b0f776f9779          Standard Bus
# d924817c-d2c8-f9b4-cd70-8b0f776f9779          Standard Bus
# 156864de-cd78-65ac-f4cc-abe292df23e2          Standard Bus
# 156864de-cd78-65ac-f4cc-abe292df23e2          Standard Bus
# 156864de-cd78-65ac-f4cc-abe292df23e2          Standard Bus
# 156864de-cd78-65ac-f4cc-abe292df23e2          Standard Bus
# ...                                                    ...
# 5a2ee223-92ac-bb9f-5b55-e3a75332aab7               Midibus
# 5a2ee223-92ac-bb9f-5b55-e3a75332aab7               Midibus
# 5a2ee223-92ac-bb9f-5b55-e3a75332aab7               Midibus
# 5a2ee223-92ac-bb9f-5b55-e3a75332aab7               Midibus
# 57a4d476-ab86-94fd-a47e-2dd623cfb1b0               Midibus
# 57a4d476-ab86-94fd-a47e-2dd623cfb1b0               Midibus
# 57a4d476-ab86-94fd-a47e-2dd623cfb1b0               Midibus
# 57a4d476-ab86-94fd-a47e-2dd623cfb1b0               Midibus
# b03f8129-1766-b454-4d69-4511cc2ca77b               Midibus
# b03f8129-1766-b454-4d69-4511cc2ca77b               Midibus
# b03f8129-1766-b454-4d69-4511cc2ca77b               Midibus
# b03f8129-1766-b454-4d69-4511cc2ca77b               Midibus
# 9c9ae174-6101-bd8e-bae5-c7a12043b593               Midibus
# 9c9ae174-6101-bd8e-bae5-c7a12043b593               Midibus
# a9b5c1ae-33ac-ee6f-fdab-c1f658d14ebc               Midibus
# b7f3e8ae-0b9f-cdcd-06a0-03b559b4340e               Midibus
# b7f3e8ae-0b9f-cdcd-06a0-03b559b4340e               Midibus
# b7f3e8ae-0b9f-cdcd-06a0-03b559b4340e               Midibus
# a060e5b7-389a-2b23-2341-556480b0aa44               Midibus
# a060e5b7-389a-2b23-2341-556480b0aa44               Midibus
# a060e5b7-389a-2b23-2341-556480b0aa44               Midibus
# a060e5b7-389a-2b23-2341-556480b0aa44               Midibus
# d3a61267-f4a9-7064-3d04-7bcb2967458b               Midibus
# d3a61267-f4a9-7064-3d04-7bcb2967458b               Midibus
# 69c37fa0-e110-4a40-38b9-49dcfe79ab56               Minibus
# 22fae19c-22dd-7844-7562-2d6153f2ef9d               Minibus
# 3ee0e001-82e5-1cf4-8c71-e0756f34e4c2               Minibus
# 56ac3f97-8eda-e8dc-7da8-fcdf3232b160               Minibus
# d9d79e7e-0247-b942-4e72-8d3422e2ea80               Minibus
# 01fa0dff-5e9a-28b8-be09-25927e72a6c0               Minibus
#
#                                                        Last Modified By  \
# Survey ID
# 5e2a9b76-63e8-715d-9fd0-02fad3d2950f  bevan.reisenberg@aurecongroup.com
# 5e2a9b76-63e8-715d-9fd0-02fad3d2950f  bevan.reisenberg@aurecongroup.com
# 5e2a9b76-63e8-715d-9fd0-02fad3d2950f  bevan.reisenberg@aurecongroup.com
# 5e2a9b76-63e8-715d-9fd0-02fad3d2950f  bevan.reisenberg@aurecongroup.com
# 6f73896f-55a9-04e3-0d86-5a27ff2e0301  bevan.reisenberg@aurecongroup.com
# 6f73896f-55a9-04e3-0d86-5a27ff2e0301  bevan.reisenberg@aurecongroup.com
# c9f4548a-c060-567f-484e-b674ff89dfb3  Katlego.mashishi@aurecongroup.com
# 2b7b0bf2-2c6f-81d4-55af-96d216ecdf48  Katlego.mashishi@aurecongroup.com
# 2b7b0bf2-2c6f-81d4-55af-96d216ecdf48  bevan.reisenberg@aurecongroup.com
# 2b7b0bf2-2c6f-81d4-55af-96d216ecdf48  bevan.reisenberg@aurecongroup.com
# 2b7b0bf2-2c6f-81d4-55af-96d216ecdf48  Katlego.mashishi@aurecongroup.com
# 2b7b0bf2-2c6f-81d4-55af-96d216ecdf48  Katlego.mashishi@aurecongroup.com
# 2b7b0bf2-2c6f-81d4-55af-96d216ecdf48  Katlego.mashishi@aurecongroup.com
# 2b7b0bf2-2c6f-81d4-55af-96d216ecdf48  Katlego.mashishi@aurecongroup.com
# 2b7b0bf2-2c6f-81d4-55af-96d216ecdf48  Katlego.mashishi@aurecongroup.com
# 8b0625fa-d153-2b91-55cd-4557341ff5ef  bevan.reisenberg@aurecongroup.com
# 8b0625fa-d153-2b91-55cd-4557341ff5ef  bevan.reisenberg@aurecongroup.com
# 8b0625fa-d153-2b91-55cd-4557341ff5ef  bevan.reisenberg@aurecongroup.com
# 8b0625fa-d153-2b91-55cd-4557341ff5ef  bevan.reisenberg@aurecongroup.com
# 8b0625fa-d153-2b91-55cd-4557341ff5ef  bevan.reisenberg@aurecongroup.com
# 8b0625fa-d153-2b91-55cd-4557341ff5ef  bevan.reisenberg@aurecongroup.com
# 8b0625fa-d153-2b91-55cd-4557341ff5ef  bevan.reisenberg@aurecongroup.com
# d924817c-d2c8-f9b4-cd70-8b0f776f9779  bevan.reisenberg@aurecongroup.com
# d924817c-d2c8-f9b4-cd70-8b0f776f9779  bevan.reisenberg@aurecongroup.com
# d924817c-d2c8-f9b4-cd70-8b0f776f9779  bevan.reisenberg@aurecongroup.com
# d924817c-d2c8-f9b4-cd70-8b0f776f9779  bevan.reisenberg@aurecongroup.com
# 156864de-cd78-65ac-f4cc-abe292df23e2  bevan.reisenberg@aurecongroup.com
# 156864de-cd78-65ac-f4cc-abe292df23e2  bevan.reisenberg@aurecongroup.com
# 156864de-cd78-65ac-f4cc-abe292df23e2  bevan.reisenberg@aurecongroup.com
# 156864de-cd78-65ac-f4cc-abe292df23e2  bevan.reisenberg@aurecongroup.com
# ...                                                                 ...
# 5a2ee223-92ac-bb9f-5b55-e3a75332aab7  bevan.reisenberg@aurecongroup.com
# 5a2ee223-92ac-bb9f-5b55-e3a75332aab7  bevan.reisenberg@aurecongroup.com
# 5a2ee223-92ac-bb9f-5b55-e3a75332aab7  bevan.reisenberg@aurecongroup.com
# 5a2ee223-92ac-bb9f-5b55-e3a75332aab7  bevan.reisenberg@aurecongroup.com
# 57a4d476-ab86-94fd-a47e-2dd623cfb1b0  Katlego.mashishi@aurecongroup.com
# 57a4d476-ab86-94fd-a47e-2dd623cfb1b0  Katlego.mashishi@aurecongroup.com
# 57a4d476-ab86-94fd-a47e-2dd623cfb1b0  Katlego.mashishi@aurecongroup.com
# 57a4d476-ab86-94fd-a47e-2dd623cfb1b0  Katlego.mashishi@aurecongroup.com
# b03f8129-1766-b454-4d69-4511cc2ca77b  bevan.reisenberg@aurecongroup.com
# b03f8129-1766-b454-4d69-4511cc2ca77b  bevan.reisenberg@aurecongroup.com
# b03f8129-1766-b454-4d69-4511cc2ca77b  bevan.reisenberg@aurecongroup.com
# b03f8129-1766-b454-4d69-4511cc2ca77b  bevan.reisenberg@aurecongroup.com
# 9c9ae174-6101-bd8e-bae5-c7a12043b593  bevan.reisenberg@aurecongroup.com
# 9c9ae174-6101-bd8e-bae5-c7a12043b593  bevan.reisenberg@aurecongroup.com
# a9b5c1ae-33ac-ee6f-fdab-c1f658d14ebc  bevan.reisenberg@aurecongroup.com
# b7f3e8ae-0b9f-cdcd-06a0-03b559b4340e  bevan.reisenberg@aurecongroup.com
# b7f3e8ae-0b9f-cdcd-06a0-03b559b4340e  bevan.reisenberg@aurecongroup.com
# b7f3e8ae-0b9f-cdcd-06a0-03b559b4340e  bevan.reisenberg@aurecongroup.com
# a060e5b7-389a-2b23-2341-556480b0aa44  bevan.reisenberg@aurecongroup.com
# a060e5b7-389a-2b23-2341-556480b0aa44  bevan.reisenberg@aurecongroup.com
# a060e5b7-389a-2b23-2341-556480b0aa44  bevan.reisenberg@aurecongroup.com
# a060e5b7-389a-2b23-2341-556480b0aa44  bevan.reisenberg@aurecongroup.com
# d3a61267-f4a9-7064-3d04-7bcb2967458b  bevan.reisenberg@aurecongroup.com
# d3a61267-f4a9-7064-3d04-7bcb2967458b  bevan.reisenberg@aurecongroup.com
# 69c37fa0-e110-4a40-38b9-49dcfe79ab56  Katlego.mashishi@aurecongroup.com
# 22fae19c-22dd-7844-7562-2d6153f2ef9d  Katlego.mashishi@aurecongroup.com
# 3ee0e001-82e5-1cf4-8c71-e0756f34e4c2  Katlego.mashishi@aurecongroup.com
# 56ac3f97-8eda-e8dc-7da8-fcdf3232b160  Katlego.mashishi@aurecongroup.com
# d9d79e7e-0247-b942-4e72-8d3422e2ea80  Katlego.mashishi@aurecongroup.com
# 01fa0dff-5e9a-28b8-be09-25927e72a6c0  Katlego.mashishi@aurecongroup.com
#
#                                            Last Modified At Nature of Damage
# Survey ID
# 5e2a9b76-63e8-715d-9fd0-02fad3d2950f    8/4/2018 1:08:42 PM     Decal Damage
# 5e2a9b76-63e8-715d-9fd0-02fad3d2950f    8/4/2018 1:06:56 PM     Paint damage
# 5e2a9b76-63e8-715d-9fd0-02fad3d2950f    8/4/2018 1:09:18 PM     Paint damage
# 5e2a9b76-63e8-715d-9fd0-02fad3d2950f    8/4/2018 1:08:06 PM     Paint damage
# 6f73896f-55a9-04e3-0d86-5a27ff2e0301   7/31/2018 9:25:58 AM     Paint damage
# 6f73896f-55a9-04e3-0d86-5a27ff2e0301   7/31/2018 9:27:34 AM            Other
# c9f4548a-c060-567f-484e-b674ff89dfb3    8/6/2018 7:44:26 AM      Body Damage
# 2b7b0bf2-2c6f-81d4-55af-96d216ecdf48    8/6/2018 7:44:29 AM      Body Damage
# 2b7b0bf2-2c6f-81d4-55af-96d216ecdf48   8/5/2018 12:28:21 PM      Body Damage
# 2b7b0bf2-2c6f-81d4-55af-96d216ecdf48   8/5/2018 12:26:56 PM            Other
# 2b7b0bf2-2c6f-81d4-55af-96d216ecdf48    8/6/2018 7:44:27 AM      Body Damage
# 2b7b0bf2-2c6f-81d4-55af-96d216ecdf48    8/6/2018 7:44:29 AM      Body Damage
# 2b7b0bf2-2c6f-81d4-55af-96d216ecdf48    8/1/2018 1:39:22 PM      Body Damage
# 2b7b0bf2-2c6f-81d4-55af-96d216ecdf48    8/1/2018 1:40:50 PM      Body Damage
# 2b7b0bf2-2c6f-81d4-55af-96d216ecdf48    8/1/2018 1:41:15 PM      Body Damage
# 8b0625fa-d153-2b91-55cd-4557341ff5ef  7/25/2018 10:08:36 AM      Body Damage
# 8b0625fa-d153-2b91-55cd-4557341ff5ef  7/25/2018 10:07:45 AM     Paint damage
# 8b0625fa-d153-2b91-55cd-4557341ff5ef  7/25/2018 10:06:32 AM     Paint damage
# 8b0625fa-d153-2b91-55cd-4557341ff5ef  7/25/2018 10:03:57 AM            Other
# 8b0625fa-d153-2b91-55cd-4557341ff5ef  7/25/2018 10:04:37 AM      Body Damage
# 8b0625fa-d153-2b91-55cd-4557341ff5ef  7/25/2018 10:03:14 AM            Other
# 8b0625fa-d153-2b91-55cd-4557341ff5ef  7/25/2018 10:05:21 AM      Body Damage
# d924817c-d2c8-f9b4-cd70-8b0f776f9779   8/4/2018 12:03:31 PM     Decal Damage
# d924817c-d2c8-f9b4-cd70-8b0f776f9779   8/4/2018 12:04:02 PM      Body Damage
# d924817c-d2c8-f9b4-cd70-8b0f776f9779   8/4/2018 12:02:48 PM      Body Damage
# d924817c-d2c8-f9b4-cd70-8b0f776f9779   8/4/2018 12:01:48 PM      Body Damage
# 156864de-cd78-65ac-f4cc-abe292df23e2  7/25/2018 10:21:39 AM     Paint damage
# 156864de-cd78-65ac-f4cc-abe292df23e2  7/25/2018 10:23:09 AM     Paint damage
# 156864de-cd78-65ac-f4cc-abe292df23e2  7/25/2018 10:25:15 AM            Other
# 156864de-cd78-65ac-f4cc-abe292df23e2  7/25/2018 10:23:40 AM      Body Damage
# ...                                                     ...              ...
# 5a2ee223-92ac-bb9f-5b55-e3a75332aab7   8/4/2018 12:35:17 PM      Body Damage
# 5a2ee223-92ac-bb9f-5b55-e3a75332aab7   8/4/2018 12:37:26 PM     Paint damage
# 5a2ee223-92ac-bb9f-5b55-e3a75332aab7   8/4/2018 12:34:47 PM     Paint damage
# 5a2ee223-92ac-bb9f-5b55-e3a75332aab7   8/4/2018 12:35:52 PM      Body Damage
# 57a4d476-ab86-94fd-a47e-2dd623cfb1b0    8/7/2018 6:19:30 AM     Decal Damage
# 57a4d476-ab86-94fd-a47e-2dd623cfb1b0   8/10/2018 9:08:19 AM     Decal Damage
# 57a4d476-ab86-94fd-a47e-2dd623cfb1b0  8/14/2018 11:35:27 AM      Body Damage
# 57a4d476-ab86-94fd-a47e-2dd623cfb1b0  8/14/2018 11:35:26 AM      Body Damage
# b03f8129-1766-b454-4d69-4511cc2ca77b   8/3/2018 10:42:17 AM      Body Damage
# b03f8129-1766-b454-4d69-4511cc2ca77b   8/3/2018 10:43:43 AM     Decal Damage
# b03f8129-1766-b454-4d69-4511cc2ca77b   8/3/2018 10:42:57 AM      Body Damage
# b03f8129-1766-b454-4d69-4511cc2ca77b   8/3/2018 10:44:21 AM      Body Damage
# 9c9ae174-6101-bd8e-bae5-c7a12043b593    8/1/2018 9:50:35 AM     Paint damage
# 9c9ae174-6101-bd8e-bae5-c7a12043b593    8/1/2018 9:49:57 AM     Paint damage
# a9b5c1ae-33ac-ee6f-fdab-c1f658d14ebc   8/2/2018 12:44:41 PM     Paint damage
# b7f3e8ae-0b9f-cdcd-06a0-03b559b4340e    8/6/2018 2:31:56 PM     Decal Damage
# b7f3e8ae-0b9f-cdcd-06a0-03b559b4340e    8/6/2018 2:30:19 PM     Paint damage
# b7f3e8ae-0b9f-cdcd-06a0-03b559b4340e    8/6/2018 2:31:06 PM     Decal Damage
# a060e5b7-389a-2b23-2341-556480b0aa44    8/6/2018 2:54:42 PM     Paint damage
# a060e5b7-389a-2b23-2341-556480b0aa44    8/6/2018 2:57:15 PM            Other
# a060e5b7-389a-2b23-2341-556480b0aa44    8/6/2018 2:56:32 PM      Body Damage
# a060e5b7-389a-2b23-2341-556480b0aa44    8/6/2018 2:55:36 PM     Decal Damage
# d3a61267-f4a9-7064-3d04-7bcb2967458b    8/1/2018 8:48:45 AM     Paint damage
# d3a61267-f4a9-7064-3d04-7bcb2967458b    8/1/2018 8:47:58 AM     Decal Damage
# 69c37fa0-e110-4a40-38b9-49dcfe79ab56   8/10/2018 9:08:18 AM      Body Damage
# 22fae19c-22dd-7844-7562-2d6153f2ef9d  8/14/2018 11:35:02 AM      Body Damage
# 3ee0e001-82e5-1cf4-8c71-e0756f34e4c2   8/10/2018 9:08:38 AM      Body Damage
# 56ac3f97-8eda-e8dc-7da8-fcdf3232b160   8/10/2018 9:08:18 AM      Body Damage
# d9d79e7e-0247-b942-4e72-8d3422e2ea80  8/14/2018 11:35:03 AM      Body Damage
# 01fa0dff-5e9a-28b8-be09-25927e72a6c0   8/10/2018 9:08:17 AM      Body Damage
#
# [257 rows x 6 columns]

# %%
filename = 'Full List.csv'
path ='D:/001_Projects/01 - GIPTN/02 - Application development/03 - Bus Inspection/02 - Reports/July 2018/%s' % (filename)
inspection_defects.to_csv(path)

filename = 'Defect List2.csv'
path ='D:/001_Projects/01 - GIPTN/02 - Application development/03 - Bus Inspection/02 - Reports/July 2018/%s' % (filename)
inspection_defects_filtered.to_csv(path)

filename = 'Body Damage2.csv'
path ='D:/001_Projects/01 - GIPTN/02 - Application development/03 - Bus Inspection/02 - Reports/July 2018/%s' % (filename)
bd_filled.to_csv(path)
